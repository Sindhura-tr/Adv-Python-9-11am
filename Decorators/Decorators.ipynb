# %% [markdown]
# ## Decorators
# ![image.png](attachment:image.png)

# %%
def multiply(x:int|float,y:int|float):
    """
    Takes 2 input parameters as x and y 
    """
    prod = x * y
    return prod

# %%
multiply(2.3,4.5)
# Out:
# 10.35

# %%
multiply([1],3)
# Out:
# [1, 1, 1]

# %%
[1]*3
# Out:
# [1, 1, 1]

# %%
multiply('a',3)
# Out:
# 'aaa'

# %%
#multiply('a',[1])

# %%
pip install ensure
# Out:
# Requirement already satisfied: ensure in c:\users\admin\desktop\adv python-9-11am\repository\venv\lib\site-packages (1.0.4)
# Requirement already satisfied: six>=1.11.0 in c:\users\admin\desktop\adv python-9-11am\repository\venv\lib\site-packages (from ensure) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from ensure import ensure_annotations

# %% [markdown]
# ### Restart and run all cells

# %%
@ensure_annotations
def multiply_2(x:int|float,y:int|float):
    """
    Takes 2 input parameters as x and y 
    """
    prod = x * y
    return prod

# %%
multiply_2(3.5,6.7)
# Out:
# 23.45

# %%
multiply_2('a',3)
# Out:
# ---------------------------------------------------------------------------
# EnsureError                               Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 multiply_2('a',3)
#
# File c:\Users\admin\Desktop\Adv Python-9-11am\repository\venv\Lib\site-packages\ensure\main.py:833, in WrappedFunction.__call__(self, *args, **kwargs)
#     831     if not isinstance(value, templ):
#     832         msg = "Argument {arg} of type {valt} to {f} " "does not match annotation type {t}"
# --> 833         raise EnsureError(msg.format(arg=arg, f=self.f, t=templ, valt=type(value)))
#     835 return self.f(*args, **kwargs)
#
# EnsureError: Argument x of type <class 'str'> to <function multiply_2 at 0x000001AC9B136CA0> does not match annotation type int | float

# %% [markdown]
# ## Syntax to create a Decorator:
#
#     def decorator_name(function):
#         def wrapper(*args,**kwargs):
#             define the purpose of decorator here
#             result = function(*args,**kwargs)
#             return result
#         return wrapper

# %%
def welcome(func):
    def wrapper(*args,**kwargs):
        print("Hi, Welcome to the page.")
        result = func(*args,**kwargs)
        print("Thankyou for using this function")
        return result
    return wrapper

# %%
@welcome
def simple_interest(p,n,r):
    return (p*n*r)/100

# %%
@welcome
@ensure_annotations
def multiply_3(x:int|float,y:int|float):
    """
    Takes 2 input parameters as x and y 
    """
    prod = x * y
    return prod

# %%
simple_interest(25000,5,4)
# Out:
# Hi, Welcome to the page.
# Thankyou for using this function
# 5000.0

# %%
si = simple_interest(25000,5,4)
print(si)
# Out:
# Hi, Welcome to the page.
# Thankyou for using this function
# 5000.0

# %%
m1 = multiply_3(345,789)
print(m1)
# Out:
# Hi, Welcome to the page.
# Thankyou for using this function
# 272205

# %%
m2 = multiply_3('a',3)
print(m2)
# Out:
# Hi, Welcome to the page.
# ---------------------------------------------------------------------------
# EnsureError                               Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 m2 = multiply_3('a',3)
#       2 print(m2)
#
# Cell In[18], line 4, in welcome.<locals>.wrapper(*args, **kwargs)
#       2 def wrapper(*args,**kwargs):
#       3     print("Hi, Welcome to the page.")
# ----> 4     result = func(*args,**kwargs)
#       5     print("Thankyou for using this function")
#       6     return result
#
# File c:\Users\admin\Desktop\Adv Python-9-11am\repository\venv\Lib\site-packages\ensure\main.py:833, in WrappedFunction.__call__(self, *args, **kwargs)
#     831     if not isinstance(value, templ):
#     832         msg = "Argument {arg} of type {valt} to {f} " "does not match annotation type {t}"
# --> 833         raise EnsureError(msg.format(arg=arg, f=self.f, t=templ, valt=type(value)))
#     835 return self.f(*args, **kwargs)
#
# EnsureError: Argument x of type <class 'str'> to <function multiply_3 at 0x000001AC9B9E4720> does not match annotation type int | float

# %%
list_nums = [23,45,67,89,102,135,167]

# %%
def generate_squares(list_data:list):
    sq_lst = []
    for i in list_data:
        sq_lst.append(i**2)
    return sq_lst

# %%
generate_squares(list_nums)
# Out:
# [529, 2025, 4489, 7921, 10404, 18225, 27889]

# %%
import time

# %%
def performance_checker(func):
    def wrapper(*args,**kwargs):
        print("Checking the performance of this function")
        start = time.perf_counter()     # notes the start time
        result = func(*args,**kwargs)   # executes the function
        stop = time.perf_counter()      # notes the stop time
        elapsed_time = stop-start       # calculates time taken to execute
        print(f"Time taken to execute this function is {elapsed_time}")
        return result
    return wrapper

# %%
@performance_checker
def generate_squares(list_data:list):
    sq_lst = []
    for i in list_data:
        sq_lst.append(i**2)
    return sq_lst

# %%
list_nums = [23,45,67,89,102,135,167]

# %%
sq_op = generate_squares(list_nums)
print(sq_op)
# Out:
# Checking the performance of this function
# Time taken to execute this function is 1.0800082236528397e-05
# [529, 2025, 4489, 7921, 10404, 18225, 27889]

# %%
@welcome
@performance_checker
def simple_interest_2(p,n,r):
    return (p*n*r)/100

# %%
si_2 = simple_interest_2(350000,10,7.9)
print(si_2)
# Out:
# Hi, Welcome to the page.
# Checking the performance of this function
# Time taken to execute this function is 2.6999041438102722e-06
# Thankyou for using this function
# 276500.0
